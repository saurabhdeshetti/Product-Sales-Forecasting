# %% [markdown]
# # EDA
#
# In this notebook, I will perform an exploratory data analysis on the dataset. I will look at the distribution of the target variable, the distribution of the features, and the relationship between the features and the target variable.

# %%
import plotly.io as pio
pio.renderers.default = "colab+notebook_connected+vscode"
import pandas as pd
import duckdb as db
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

sns.set_theme(style="whitegrid")
pio.templates.default = "seaborn"

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df=pd.read_parquet('../../data/processed/train_enhanced.parquet')
df.head()
# Out:
#          ID  Store_id Store_Type Location_Type Region_Code       Date  \
# 0  T1000001         1         S1            L3          R1 2018-01-01
# 1  T1000002       253         S4            L2          R1 2018-01-01
# 2  T1000003       252         S3            L2          R1 2018-01-01
# 3  T1000004       251         S2            L3          R1 2018-01-01
# 4  T1000005       250         S2            L3          R4 2018-01-01
#
#    Holiday  Discount  Orders     Sales  ...  Year  Quarter  Week  \
# 0        1         1       9   7011.84  ...  2018        1     1
# 1        1         1      60  51789.12  ...  2018        1     1
# 2        1         1      42  36868.20  ...  2018        1     1
# 3        1         1      23  19715.16  ...  2018        1     1
# 4        1         1      62  45614.52  ...  2018        1     1
#
#   Week_of_Month  Is_Weekend  cluster  log_Sales  log_Orders  sqrt_Sales  \
# 0             1           0        3   8.855498    2.302585   83.736730
# 1             1           0        2  10.854955    4.110874  227.572230
# 2             1           0        1  10.515132    3.761200  192.010937
# 3             1           0        4   9.889194    3.178054  140.410683
# 4             1           0        4  10.728003    4.143135  213.575560
#
#    sqrt_Orders
# 0     3.000000
# 1     7.745967
# 2     6.480741
# 3     4.795832
# 4     7.874008
#
# [5 rows x 25 columns]

# %%
# df['Region_Discount'] = df['Region_Code'].astype(str) + '_' + df['Discount'].astype(str)
# df['Region_Holiday'] = df['Region_Code'].astype(str) + '_' + df['Holiday'].astype(str)

# %%
df["log_Sales"] = np.log1p(df["Sales"])
df["log_Orders"] = np.log1p(df["Orders"])
df["sqrt_Sales"] = np.sqrt(df["Sales"])
df["sqrt_Orders"] = np.sqrt(df["Orders"])

# %%
df.to_parquet('../../data/processed/train_enhanced.parquet', index=False)
# df=pd.read_parquet('../../data/processed/train_enhanced.parquet')

# %%
df
# Out:
#               ID  Store_id Store_Type Location_Type Region_Code       Date  \
# 0       T1000001         1         S1            L3          R1 2018-01-01
# 1       T1000002       253         S4            L2          R1 2018-01-01
# 2       T1000003       252         S3            L2          R1 2018-01-01
# 3       T1000004       251         S2            L3          R1 2018-01-01
# 4       T1000005       250         S2            L3          R4 2018-01-01
# ...          ...       ...        ...           ...         ...        ...
# 188335  T1188336       149         S2            L3          R2 2019-05-31
# 188336  T1188337       153         S4            L2          R1 2019-05-31
# 188337  T1188338       154         S1            L3          R2 2019-05-31
# 188338  T1188339       155         S3            L1          R2 2019-05-31
# 188339  T1188340       152         S2            L1          R1 2019-05-31
#
#         Holiday  Discount  Orders     Sales  ...  Year  Quarter  Week  \
# 0             1         1       9   7011.84  ...  2018        1     1
# 1             1         1      60  51789.12  ...  2018        1     1
# 2             1         1      42  36868.20  ...  2018        1     1
# 3             1         1      23  19715.16  ...  2018        1     1
# 4             1         1      62  45614.52  ...  2018        1     1
# ...         ...       ...     ...       ...  ...   ...      ...   ...
# 188335        1         1      51  37272.00  ...  2019        2    22
# 188336        1         0      90  54572.64  ...  2019        2    22
# 188337        1         0      56  31624.56  ...  2019        2    22
# 188338        1         1      70  49162.41  ...  2019        2    22
# 188339        1         0      47  37977.00  ...  2019        2    22
#
#        Week_of_Month  Is_Weekend  cluster  log_Sales  log_Orders  sqrt_Sales  \
# 0                  1           0        3   8.855498    2.302585   83.736730
# 1                  1           0        2  10.854955    4.110874  227.572230
# 2                  1           0        1  10.515132    3.761200  192.010937
# 3                  1           0        4   9.889194    3.178054  140.410683
# 4                  1           0        4  10.728003    4.143135  213.575560
# ...              ...         ...      ...        ...         ...         ...
# 188335             5           0        4  10.526024    3.951244  193.059576
# 188336             5           0        2  10.907306    4.510860  233.607877
# 188337             5           0        3  10.361721    4.043051  177.832955
# 188338             5           0        1  10.802905    4.262680  221.725980
# 188339             5           0        4  10.544762    3.871201  194.876884
#
#         sqrt_Orders
# 0          3.000000
# 1          7.745967
# 2          6.480741
# 3          4.795832
# 4          7.874008
# ...             ...
# 188335     7.141428
# 188336     9.486833
# 188337     7.483315
# 188338     8.366600
# 188339     6.855655
#
# [188340 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Store_id', 'Store_Type', 'Location_Type', 'Region_Code', 'Date',
#        'Holiday', 'Discount', 'Orders', 'Sales', 'Day_of_Week_Name', 'Day',
#        'Day_of_Week', 'Month_Name', 'Month', 'Year', 'Quarter', 'Week',
#        'Week_of_Month', 'Is_Weekend', 'cluster', 'log_Sales', 'log_Orders',
#        'sqrt_Sales', 'sqrt_Orders'],
#       dtype='object')

# %% [markdown]
# ## Univariate Analysis
#
# In this section we will perform univariate analysis on the data. We will look at the distribution of the target variable and the features. We will also look at the missing values

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='Orders', bins=100, kde=True);
plt.title('Order Count distribution');
plt.xlabel('Order Count');

# %% [markdown]
# <b style='padding: 4px 10px 6px 10px;border-radius: 5px;background: #009688;color: #fff;display: inline-block;'>Observations</b>
# - We can see that most of the order count for each store is around 50 - 80

# %%
plt.figure(figsize=(6, 6))
sns.boxplot(data=df, y='Orders');
plt.title('Order Count distribution');

# %% [markdown]
# <b style='padding: 4px 10px 6px 10px;border-radius: 5px;background: #009688;color: #fff;display: inline-block;'>Observations</b>
#
# - We can see that most of the order count for each store is around 50 - 80

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='Sales', bins=100, kde=True);
plt.title('Sales Count distribution');
plt.xlabel('Sales Count');

# %% [markdown]
# <b style='padding: 4px 10px 6px 10px;border-radius: 5px;background: #009688;color: #fff;display: inline-block;'>Observations</b>
#
# - We can see that most of the sales are around 50000

# %%
plt.figure(figsize=(6, 6))
sns.boxplot(data=df, y='Sales');
plt.title('Sales distribution');

# %% [markdown]
# # Bivariate Analysis
#
# ## Sales

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=df, y='Sales',  hue='Holiday', gap=0.1);
plt.title('Sales distribution by Holiday Type');

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=df, y='Sales',  hue='Discount', gap=0.1);
plt.title('Sales distribution by Discount Type');

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=df, y='Sales',  hue='Store_Type', gap=0.1);
plt.title('Sales distribution by Store Type');

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=df, y='Sales',  hue='Region_Code', gap=0.1);
plt.title('Sales distribution by Region');

# %% [markdown]
# **Sales Distribution by Location**

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=df, y='Sales',  hue='Location_Type', gap=0.1);
plt.title('Sales distribution by Location Type');

# %% [markdown]
# <b style='padding: 4px 10px 6px 10px;border-radius: 5px;background: #009688;color: #fff;display: inline-block;'>Observations</b>
# - Location type L2 has the higher number of sales compared to other location types
# - Location type L5 has the lowest number of sales

# %% [markdown]
# **Top Stores with highest sales**

# %%
db.sql("""
    select Store_id, round(sum(Sales),0) as Total_Sales, sum(Orders) as Total_Orders from df group by Store_id order by Total_Sales desc limit 10
""").df().plot(kind='bar', x='Store_id', y='Total_Sales', figsize=(12, 6), title='Top 10 Stores by Sales', rot=0);

# %% [markdown]
# <b style='padding: 4px 10px 6px 10px;border-radius: 5px;background: #009688;color: #fff;display: inline-block;'>Observations</b>
# - From above plot we can see that Store 175 has highest number of sales

# %%
_=db.sql("""
       select 
         distinct Region_Code
         , count(distinct store_id) as store_count,
       from df
         group by 1
       order by 2 desc
""")
print(_)
_.df().plot(kind='bar', x='Region_Code', y='store_count', figsize=(12, 6), title='Store Count by Region', rot=0);
# Out:
# ┌─────────────┬─────────────┐
# │ Region_Code │ store_count │
# │   varchar   │    int64    │
# ├─────────────┼─────────────┤
# │ R1          │         124 │
# │ R2          │         105 │
# │ R3          │          86 │
# │ R4          │          50 │
# └─────────────┴─────────────┘

# %% [markdown]
# <b style='padding: 4px 10px 6px 10px;border-radius: 5px;background: #009688;color: #fff;display: inline-block;'>Observations</b>
# - There are 124 stores in R1 region, 105 in R2, 86 in R3 and 50 stores in R4 region

# %%
db.sql("""
    select Region_Code, round(sum(Sales),0) as Total_Sales, sum(Orders) as Total_Orders from df group by Region_Code order by Total_Sales desc
""").df().plot(kind='bar', x='Region_Code', y=['Total_Sales', 'Total_Orders'], figsize=(12, 6), title='Top Regions', secondary_y='Total_Orders', rot=0);

# %% [markdown]
# <b style='padding: 4px 10px 6px 10px;border-radius: 5px;background: #009688;color: #fff;display: inline-block;'>Observations</b>
#
# - We can see that Reagion R1 has the highest number of sales and orders
# - Region R4 has the lowest number of sales and orders

# %%
db.sql("""
    select Store_Type, round(sum(Sales),0) as Total_Sales, sum(Orders) as Total_Orders from df group by Store_Type order by Total_Sales desc
""").df().plot(kind='bar', x='Store_Type', y=['Total_Sales', 'Total_Orders'], figsize=(12, 6), title='Top Store Types', secondary_y='Total_Orders', rot=0);

# %% [markdown]
# <b style='padding: 4px 10px 6px 10px;border-radius: 5px;background: #009688;color: #fff;display: inline-block;'>Observations</b>
#
# - We can see that Store type S1 has the highest number of sales and orders
# - Store type S2 has the lowest number of sales and orders

# %%
db.sql("""
    select Store_Type, round(avg(Sales),0) as Avg_Sales, avg(Orders) as Total_Orders from df group by Store_Type order by Avg_Sales desc
""").df().plot(kind='bar', x='Store_Type', y=['Avg_Sales', 'Total_Orders'], figsize=(12, 6), title='Top Store Types', secondary_y='Total_Orders', rot=0);

# %%
db.sql("""
    select Location_Type, round(sum(Sales),0) as Total_Sales, sum(Orders) as Total_Orders from df group by Location_Type order by Total_Sales desc
""").df().plot(kind='bar', x='Location_Type', y=['Total_Sales', 'Total_Orders'], figsize=(12, 6), title='Top Location', secondary_y='Total_Orders', rot=0);

# %% [markdown]
# <b style='padding: 4px 10px 6px 10px;border-radius: 5px;background: #009688;color: #fff;display: inline-block;'>Observations</b>
#
# - We can see that Location type L1 has the highest number of sales and orders
# - Location type L4 has the lowest number of sales and orders

# %%
db.sql("""
    select Year, round(sum(Sales),0) as Total_Sales, sum(Orders) as Total_Orders from df group by Year order by Year
""").df().plot(kind='bar', x='Year', y=['Total_Sales', 'Total_Orders'], figsize=(12, 6), title='Sales by Year', secondary_y='Total_Orders');

# %%
db.sql("""
    select Month, Month_Name, round(avg(Sales),0) as Total_Sales, avg(Orders) as Total_Orders from df group by Month, Month_Name, month(Date) order by month(Date)
""").df().plot(kind='bar', x='Month_Name', y=['Total_Sales', 'Total_Orders'], figsize=(12, 6), title='Sales by Month', secondary_y='Total_Orders', rot=0);

# %%
db.sql("""
    select Day_of_Week, Day_of_Week_Name, round(avg(Sales),0) as Total_Sales, avg(Orders) as Total_Orders from df group by Day_of_Week,Day_of_Week_Name, weekday(Date)  order by weekday(Date)
""").df().plot(kind='bar', x='Day_of_Week_Name', y=['Total_Sales', 'Total_Orders'], figsize=(12, 6), title='Sales by Day_of_Week', secondary_y='Total_Orders');

# %% [markdown]
# **Daily Sales Analysis Per Week**

# %%
df[["Day_of_Week", "Day_of_Week_Name"]].drop_duplicates().sort_values(by="Day_of_Week").reset_index(drop=True)
# Out:
#    Day_of_Week Day_of_Week_Name
# 0            0           Monday
# 1            1          Tuesday
# 2            2        Wednesday
# 3            3         Thursday
# 4            4           Friday
# 5            5         Saturday
# 6            6           Sunday

# %%
df[["Day_of_Week", "Day_of_Week_Name"]].head(7)
# Out:
#    Day_of_Week Day_of_Week_Name
# 0            0           Monday
# 1            0           Monday
# 2            0           Monday
# 3            0           Monday
# 4            0           Monday
# 5            0           Monday
# 6            0           Monday

# %%
df.groupby("Day_of_Week").agg({"Sales": "mean"}).plot(kind='line', figsize=(12, 6), title='Sales by Day of the Week');
plt.xticks(np.arange(7), ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']);
plt.xlabel('Day of the Week');

# %% [markdown]
# <b style='padding: 4px 10px 6px 10px;border-radius: 5px;background: #009688;color: #fff;display: inline-block;'>Observations</b>
#
# - Sales are highest during Saturday and Sunday

# %% [markdown]
# **Average sales by Week of Month**

# %%
df.groupby("Week_of_Month").agg({"Sales": "mean"}).reset_index().plot(kind='line', x='Week_of_Month', y='Sales', figsize=(12, 6), title='Sales by Week of the Month');
plt.xticks(np.arange(1, 6), ['Week 1', 'Week 2', 'Week 3', 'Week 4', 'Week 5']);
plt.xlabel('Week of the Month');

# %% [markdown]
# <b style='padding: 4px 10px 6px 10px;border-radius: 5px;background: #009688;color: #fff;display: inline-block;'>Observations</b>
# - There is higher number of sales during the first week of the month
# - There is a slight increase in sales during the last week of the month
# - The sales is lowest during the 4th week of the month

# %% [markdown]
# **Average Sales by Month**

# %%
df.groupby(df["Date"].dt.month).agg({"Sales": "mean"}).plot(kind='line', figsize=(12, 6), title='Sales by Month');
plt.xticks(np.arange(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']);

# %% [markdown]
# <b style='padding: 4px 10px 6px 10px;border-radius: 5px;background: #009688;color: #fff;display: inline-block;'>Observations</b>
#
# - The sales is highest during the month of May July, December and January

# %% [markdown]
# **Average Sales by Days of Month**

# %%
df.groupby("Day").agg({"Sales": "mean"}).plot(kind='line', figsize=(12, 6), title='Sales by Days of Month');

# %% [markdown]
# <b style='padding: 4px 10px 6px 10px;border-radius: 5px;background: #009688;color: #fff;display: inline-block;'>Observations</b>
# - There is high number of sales during the 5 days of the month

# %% [markdown]
# # Multi-variate Analysis

# %% [markdown]
# **Sales vs Orders by Store for Regions**

# %%
agg_df=db.sql("""
select Store_id,avg(Sales) as Avg_Sales, avg(Orders) as Avg_Orders, Region_Code from df group by Store_id, Region_Code
""").to_df()
fig=px.scatter(agg_df, x='Avg_Orders', y='Avg_Sales', title='Sales vs Orders by Region', hover_data=['Store_id'], color='Region_Code', );
fig.update_traces(marker=dict(size=10))
fig.update_layout(
    height=1000,
    width=1200,
)
fig.show();
# Out:
# <div>                            <div id="b26fb9bb-2c41-4783-9afc-4cba0481655e" class="plotly-graph-div" style="height:1000px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b26fb9bb-2c41-4783-9afc-4cba0481655e")) {                    Plotly.newPlot(                        "b26fb9bb-2c41-4783-9afc-4cba0481655e",                        [{"customdata":[[136],[93],[68],[349],[244],[177],[193],[147],[14],[106],[23],[322],[40],[199],[241],[118],[73],[50],[255],[214],[36],[22],[78],[226],[69],[114],[297],[256],[86],[258],[135],[266],[121],[21],[79],[331],[304],[33],[286],[232],[108],[133],[273],[274],[230],[260],[250],[169],[174],[278]],"hovertemplate":"Region_Code=R4\u003cbr\u003eAvg_Orders=%{x}\u003cbr\u003eAvg_Sales=%{y}\u003cbr\u003eStore_id=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R4","marker":{"color":"rgb(76,114,176)","symbol":"circle","size":10},"mode":"markers","name":"R4","orientation":"v","showlegend":true,"x":[31.8546511627907,52.833333333333336,65.8062015503876,65.88953488372093,42.92248062015504,45.96705426356589,40.30232558139535,110.55426356589147,76.79263565891473,59.90891472868217,52.94767441860465,41.87984496124031,57.38565891472868,49.71124031007752,60.75581395348837,45.689922480620154,72.63178294573643,73.9108527131783,73.1046511627907,51.37984496124031,55.71124031007752,54.52325581395349,50.486434108527135,36.298449612403104,53.22868217054263,72.41279069767442,45.62015503875969,63.71705426356589,50.80232558139535,37.83720930232558,52.40503875968992,56.46705426356589,64.87984496124031,74.63178294573643,36.99612403100775,53.14147286821706,54.87015503875969,87.2422480620155,105.42248062015504,53.67054263565891,64.7422480620155,63.57364341085271,36.42054263565891,89.34496124031008,35.05813953488372,54.67635658914729,41.40891472868217,64.90697674418605,53.85271317829457,97.12403100775194],"xaxis":"x","y":[22622.779244186055,36928.35220930233,47558.32360465117,43109.86639534885,26246.904593023253,33452.494360465105,28894.7938372093,63217.85744186048,56756.36279069768,38370.2386627907,37594.04953488372,29943.603895348835,42429.173081395355,34263.30453488372,43472.71610465116,33882.489941860455,53277.6015116279,49572.35918604652,51062.30203488372,35622.64656976744,34683.61924418605,42246.44377906977,35057.53726744186,23202.095058139537,34486.407965116276,46851.2163372093,29827.807441860466,48304.08069767442,34409.24999999999,25993.573720930228,38311.4476744186,36808.36244186047,45410.006220930234,49477.32511627908,24957.46622093023,36405.85395348837,34853.82122093023,57172.76424418605,64028.64936046512,35578.56593023255,44973.81930232558,39474.13773255814,27407.723372093027,58477.62203488373,25076.68534883721,35944.68860465116,29409.917209302326,47240.10709302326,37054.57,55767.9283139535],"yaxis":"y","type":"scatter"},{"customdata":[[209],[172],[102],[150],[219],[45],[95],[6],[252],[310],[85],[173],[25],[83],[115],[354],[34],[253],[97],[80],[67],[296],[18],[275],[347],[197],[336],[330],[259],[344],[315],[20],[242],[346],[228],[190],[338],[89],[358],[81],[138],[323],[1],[292],[16],[82],[59],[62],[3],[337],[352],[160],[58],[356],[281],[263],[339],[71],[298],[283],[131],[251],[303],[191],[261],[157],[287],[268],[182],[277],[332],[152],[109],[146],[134],[211],[267],[201],[295],[125],[175],[13],[105],[361],[312],[215],[227],[145],[316],[328],[188],[313],[254],[208],[360],[9],[195],[348],[305],[210],[137],[216],[317],[262],[187],[357],[342],[129],[326],[140],[39],[206],[217],[153],[291],[57],[225],[91],[11],[257],[15],[183],[269],[309]],"hovertemplate":"Region_Code=R1\u003cbr\u003eAvg_Orders=%{x}\u003cbr\u003eAvg_Sales=%{y}\u003cbr\u003eStore_id=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R1","marker":{"color":"rgb(221,132,82)","symbol":"circle","size":10},"mode":"markers ...

# %% [markdown]
# <b style='padding: 4px 10px 6px 10px;border-radius: 5px;background: #009688;color: #fff;display: inline-block;'>Observations</b>
# - From above plot we can see that there is no clear separation between the stores based on the region

# %% [markdown]
# **Sales vs Orders by Store for Store type**

# %%
agg_df=db.sql("""
select Store_id,avg(Sales) as Avg_Sales, avg(Orders) as Avg_Orders, Store_Type, from df group by Store_id, Store_Type
""").to_df()

fig=px.scatter(agg_df, x='Avg_Orders', y='Avg_Sales', title='Sales vs Orders by Store', hover_data=['Store_id'], color='Store_Type');
fig.update_traces(marker=dict(size=10))
fig.update_layout(
    height=1000,
    width=1200,
)
fig.show();
# Out:
# <div>                            <div id="e0027d34-8e04-4dd4-a84e-9b5b8c3a5f5e" class="plotly-graph-div" style="height:1000px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0027d34-8e04-4dd4-a84e-9b5b8c3a5f5e")) {                    Plotly.newPlot(                        "e0027d34-8e04-4dd4-a84e-9b5b8c3a5f5e",                        [{"customdata":[[21],[74],[334],[129],[326],[319],[91],[239],[288],[66],[191],[120],[28],[182],[13],[143],[215],[155],[14],[188],[53],[208],[75],[264],[178],[64],[2],[356],[73],[50],[255],[181],[114],[321],[124],[325],[246],[348],[96],[317],[45],[95],[7],[252],[240],[190],[358],[81]],"hovertemplate":"Store_Type=S3\u003cbr\u003eAvg_Orders=%{x}\u003cbr\u003eAvg_Sales=%{y}\u003cbr\u003eStore_id=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"S3","marker":{"color":"rgb(76,114,176)","symbol":"circle","size":10},"mode":"markers","name":"S3","orientation":"v","showlegend":true,"x":[74.63178294573643,75.77713178294573,77.16279069767442,70.81976744186046,76.16279069767442,75.1453488372093,75.44573643410853,72.35077519379846,78.30426356589147,70.98643410852713,73.3953488372093,73.47286821705427,76.97674418604652,70.72093023255815,74.04651162790698,76.1375968992248,74.37209302325581,70.39728682170542,76.79263565891473,71.00581395348837,71.49031007751938,72.65503875968992,76.16472868217055,69.54069767441861,70.67441860465117,72.14341085271317,76.19767441860465,69.61821705426357,72.63178294573643,73.9108527131783,73.1046511627907,74.79263565891473,72.41279069767442,71.8546511627907,77.09496124031008,68.20542635658914,72.27131782945736,74.4515503875969,77.65310077519379,75.41666666666667,73.16279069767442,70.07751937984496,73.84302325581395,77.0251937984496,77.45542635658914,75.40310077519379,71.93604651162791,70.55038759689923],"xaxis":"x","y":[49477.32511627908,47613.488081395335,53586.6919767442,41130.84005813954,47228.435406976736,48218.4796511628,47365.910988372096,46068.71441860466,51733.56883720931,39500.716337209305,41824.794883720926,55025.245,53921.0811627907,40034.05604651162,39300.12220930233,56113.20476744186,51294.21145348837,45546.949825581396,56756.36279069768,54165.354186046505,44939.329593023256,42026.93052325581,52772.40860465116,45512.15284883722,47465.72255813953,44305.23720930232,46333.86319767442,37612.83325581396,53277.6015116279,49572.35918604652,51062.30203488372,42443.226744186046,46851.2163372093,44324.6611627907,54132.104127906976,44893.55965116279,47211.22691860466,43158.974186046515,47396.08703488371,41869.482034883724,43062.902151162794,39792.37139534884,45164.05906976744,51991.910872093016,49657.6375,40640.00930232558,45090.41744186046,50561.13436046512],"yaxis":"y","type":"scatter"},{"customdata":[[187],[112],[331],[341],[52],[248],[206],[35],[304],[291],[307],[225],[185],[362],[194],[232],[257],[183],[269],[290],[108],[309],[333],[221],[363],[104],[23],[65],[60],[287],[19],[268],[40],[44],[277],[199],[241],[156],[154],[109],[318],[134],[119],[99],[276],[295],[93],[68],[302],[349],[361],[12],[145],[165],[29],[196],[328],[314],[313],[343],[233],[106],[151],[1],[292],[16],[148],[164],[59],[51],[238],[166],[58],[285],[270],[132],[281],[192],[263],[247],[236],[84],[161],[170],[214],[41],[26],[42],[69],[25],[122],[207],[63],[34],[4],[224],[107],[80],[229],[141],[296],[38],[144],[256],[86],[72],[133],[70],[9],[345],[301],[260],[92],[130],[210],[335],[117],[24],[169],[128],[218],[174],[17],[262],[48],[324],[209],[172],[235],[31],[205],[37],[249],[54],[135],[299],[266],[121],[353],[167],[163],[179],[101],[347],[36],[5],[22],[78],[111],[213],[271],[61],[90],[184],[344],[43],[306],[20],[180],[350],[103],[282],[55],[228],[89],[351],[100],[30],[138],[32],[27],[323]],"hovertemplate":"Store_Type=S1\u003cbr\u003eAvg_Orders=%{x}\u003cbr\u003eAvg_Sales=%{y}\u003cbr\u003eStore_ ...

# %% [markdown]
# <b style='padding: 4px 10px 6px 10px;border-radius: 5px;background: #009688;color: #fff;display: inline-block;'>Observations</b>
# - From above plot we can see clear distribution of sales and orders by store for each Store type

# %% [markdown]
# **Sales vs Orders by Store for Location Type**

# %%
agg_df=db.sql("""
select Store_id,avg(Sales) as Avg_Sales, avg(Orders) as Avg_Orders, Location_Type, from df group by Store_id, Location_Type
""").to_df()

fig=px.scatter(agg_df, x='Avg_Orders', y='Avg_Sales', title='Sales vs Orders by Location', hover_data=['Store_id'], color='Location_Type');
fig.update_traces(marker=dict(size=10))
fig.update_layout(
    height=1000,
    width=1200,
)
fig.show();
# Out:
# <div>                            <div id="7de7fd72-dc6f-4ab8-945a-8bec9bb3c52e" class="plotly-graph-div" style="height:1000px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7de7fd72-dc6f-4ab8-945a-8bec9bb3c52e")) {                    Plotly.newPlot(                        "7de7fd72-dc6f-4ab8-945a-8bec9bb3c52e",                        [{"customdata":[[240],[336],[330],[127],[184],[315],[202],[311],[139],[282],[338],[81],[30],[82],[75],[3],[178],[10],[337],[160],[176],[73],[339],[50],[255],[131],[243],[274],[87],[169],[128],[211],[267],[125],[175],[143],[68],[308],[105],[47],[312],[215],[227],[316],[147],[14],[188],[171],[324],[102],[150],[219],[54],[280],[329],[252],[163],[126],[294],[85],[21],[334],[222],[198],[153],[33],[11],[158],[288],[286],[15],[173],[115],[231],[212],[354],[253],[94],[224],[124],[256],[72],[303],[261],[120],[65],[28],[157],[8],[268],[340],[123],[146],[284]],"hovertemplate":"Location_Type=L2\u003cbr\u003eAvg_Orders=%{x}\u003cbr\u003eAvg_Sales=%{y}\u003cbr\u003eStore_id=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"L2","marker":{"color":"rgb(76,114,176)","symbol":"circle","size":10},"mode":"markers","name":"L2","orientation":"v","showlegend":true,"x":[77.45542635658914,120.57170542635659,97.05426356589147,98.36434108527132,59.24612403100775,129.63565891472868,84.60271317829458,99.88565891472868,103.37984496124031,65.24418604651163,96.3546511627907,70.55038759689923,68.70542635658914,113.33720930232558,76.16472868217055,115.28488372093024,70.67441860465117,86.22286821705427,169.9748062015504,155.3003875968992,106.09883720930233,72.63178294573643,109.05232558139535,73.9108527131783,73.1046511627907,124.70930232558139,79.48449612403101,89.34496124031008,97.17829457364341,64.90697674418605,63.53294573643411,105.0077519379845,81.0562015503876,102.56589147286822,182.90891472868216,76.1375968992248,65.8062015503876,90.13565891472868,85.73062015503876,97.95348837209302,159.21124031007753,74.37209302325581,79.25581395348837,80.73643410852713,110.55426356589147,76.79263565891473,71.00581395348837,90.91279069767442,66.90697674418605,92.9108527131783,115.82170542635659,127.80038759689923,57.64147286821706,112.0077519379845,84.62209302325581,77.0251937984496,68.52713178294573,138.6627906976744,115.53294573643412,124.23449612403101,74.63178294573643,77.16279069767442,104.30813953488372,95.76744186046511,135.44767441860466,87.2422480620155,110.7248062015504,119.3624031007752,78.30426356589147,105.42248062015504,110.75968992248062,115.83333333333333,117.51162790697674,98.02131782945736,105.29069767441861,118.73255813953489,93.50581395348837,83.47286821705427,64.6937984496124,77.09496124031008,63.71705426356589,69.01550387596899,115.76550387596899,84.51550387596899,73.47286821705427,70.2577519379845,76.97674418604652,108.8062015503876,87.03682170542636,64.66666666666667,88.87403100775194,78.03294573643412,154.75,83.0562015503876],"xaxis":"x","y":[49657.6375,68747.66976744187,56402.11063953489,60274.130406976736,43911.63133720929,71348.54947674419,54077.21866279069,58538.77313953488,63882.74726744187,51246.134069767446,60020.555,50561.13436046512,47102.779767441854,62960.14994186046,52772.40860465116,62479.44895348837,47465.72255813953,58177.004534883716,95624.84093023255,83666.54081395348,68539.32790697673,53277.6015116279,61614.80953488371,49572.35918604652,51062.30203488372,68161.4469767442,56309.129883720925,58477.62203488373,71577.55168604651,47240.10709302326,44912.77819767443,59142.081104651166,51765.08680232558,58602.75436046513,101860.95959302325,56113.20476744186,47558.32360465117,55049.52720930232,52342.307790697676,57459.2273255814,86996.74075581395,51294.21145348837,50912.283953488375,52729.36813953488,63217.85744186048,56756.36279069768,54165.354186046505,56155.05069767443,51030.57511627908, ...

# %% [markdown]
# <b style='padding: 4px 10px 6px 10px;border-radius: 5px;background: #009688;color: #fff;display: inline-block;'>Observations</b>
# - From above plot we can see clear distribution of sales and orders by store for each Location type
